# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': {'$eq': 20}}
result = list(establishments.find(query))

# Use count_documents to display the number of documents in the result
print(establishments.count_documents({'scores.Hygiene': {'$eq': 20}}))
# Display the first document in the results using pprint
pprint(result[0])
# Out:
# 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6757a611081b88675f2b2235'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
hygiene_20_df = pd.DataFrame(result)

# Display the number of rows in the DataFrame
print(f"Number of rows: {len(hygiene_20_df)}")
# Display the first 10 rows of the DataFrame
hygiene_20_df.head(10)
# Out:
# Number of rows: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  6757a611081b88675f2b2235   110681                  0
# 1  6757a612081b88675f2b25b6   612039                  0
# 2  6757a614081b88675f2b28c0   730933                  0
# 3  6757a614081b88675f2b2aae   172735                  0
# 4  6757a614081b88675f2b2abd   172953                  0
# 5  6757a61d081b88675f2b345c   512854                  0
# 6  6757a61d081b88675f2b367d  1537089                  0
# 7  6757a62e081b88675f2b4ba8   155648                  0
# 8  6757a630081b88675f2b4fec  1012883                  0
# 9  6757a633081b88675f2b57fe   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
establishments.find_one()
# Out:
# {'_id': ObjectId('6757a604081b88675f2b0703'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': Decimal128('1.195625'),
#   'latitude': Decimal128('51.083812')},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %%
#testing the queries
list(establishments.find({'LocalAuthorityName' :{'$regex': "London"}}))
# Out:
# [{'_id': ObjectId('6757a622081b88675f2b3c50'),
#   'FHRSID': 621707,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000025307',
#   'BusinessName': "Charlie's",
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#   'AddressLine2': 'Sheppy Kent',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'ME12',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-10-18T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.508551'),
#    'latitude': Decimal128('51.369321')},
#   'RightToReply': '',
#   'Distance': 4627.439467780196,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/621707'}]},
#  {'_id': ObjectId('6757a624081b88675f2b3f76'),
#   'FHRSID': 1130836,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000034075',
#   'BusinessName': 'Mv City Cruises Erasmus',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Cherry Garden Pier',
#   'AddressLine2': 'Cherry Garden Street Rotherhithe',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': '',
#   'PostCode': 'TN4 8HR',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-05-14T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.249255999922752'),
#    'latitude': Decimal128('51.1236228942871')},
#   'RightToReply': '',
#   'Distance': 4627.8731788858,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1130836'}]},
#  {'_id': ObjectId('6757a62e081b88675f2b4ac3'),
#   'FHRSID': 293783,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000002614',
#   'BusinessName': 'Benfleet Motor Yacht Club',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Ferry Road',
#   'AddressLine2': 'South Benfleet Essex',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'SS7 1NF',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2018-11-02T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.561954'),
#    'latitude': Decimal128('51.543831')},
#   'RightToReply': '',
#   'Distance': 4631.968418191259,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/293783'}]},
#  {'_id': ObjectId('6757a630081b88675f2b50d0'),
#   'FHRSID': 1523645,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000038853',
#   'BusinessName': 'Gourmet Kitchen',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': '1 London Gateway',
#   'AddressLine2': 'London Gateway Drive Stanford-Le-Hope',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'SS17 9DY',
#   'Phone': '',
#   'RatingValue': '3',
#   'RatingKey': 'fhrs_3_en-gb',
#   'RatingDate': '2022-05-05T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.4596371'),
#    'latitude': Decimal128('51.5100659')},
#   'RightToReply': '',
#   'Distance': 4634.42812137316,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1523645'}]},
#  {'_id': ObjectId('6757a633081b88675f2b58c3'),
#   'FHRSID': 1315095,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000036464',
#   'BusinessName': 'Coombs Catering t/a The Lock and Key',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Leslie Ford House',
#   'AddressLine2': 'Tilbury',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': '',
#   'PostCode': 'RM18 7EH',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-12-04T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.346336990594864'),
#    'latitude': Decimal128('51.4640655517578')},
#   'RightToReply': '',
#   'Distance': 4636.846754121153,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1315095'}]},
#  {'_id': ObjectId('6757a633081b88675f2b58c4'),
#   'FHRSID': 294474,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000014647',
#   'BusinessName': 'Tilbury Seafarers Centre',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Tenants Row Tilbury Docks',
#   'AddressLine2': 'Tilbury Essex',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'RM18 7EH',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-11-02T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.346325'),
#    'latitude': Decimal128('51.464078')},
#   'RightToReply': '',
#   'Distance': 4636.847649796817,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/294474'}]},
#  {'_id': ObjectId('6757a636081b88675f2b5fcc'),
#   'FHRSID': 294900,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000019066',
#   'BusinessName': 'Mv Valulla',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Reeds River Cruises LtdKings ReachRiver ThamesSouthwark',
#   'AddressLine2': 'London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'RM15 5QY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2016-08-23T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.287555'),
#    'latitude': Decimal128('51.504071')},
#   'RightToReply': '',
#   'Distance': 4640.460834256174,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/294900'}]},
#  {'_id': ObjectId('6757a648081b88675f2b80d6'),
#   'FHRSID': 1252616,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000035653',
#   'BusinessName': 'Froottree',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Tereza Joanne King George V Lock',
#   'AddressLine2': 'Woolwich Manor Way London',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': '',
#   'PostCode': 'E16 2NJ',
#   'Phone': '',
#   'RatingValue': None,
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingDate': '1901-01-01T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.0693250000476837'),
#    'latitude': Decimal128('51.5011100769043')},
#   'RightToReply': '',
#   'Distance': 4648.300000043045,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1252616'}]},
#  {'_id': ObjectId('6757a648081b88675f2b80da'),
#   'FHRSID': 293756,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000002538',
#   'BusinessName': 'Tereza Joanne',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Funcraft UK Ltd King George V Dock Woolwich Manor Way',
#   'AddressLine2': 'London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E16 2NJ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-07-09T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.069286'),
#    'latitude': Decimal128('51.501121')},
#   'RightToReply': '',
#   'Distance': 4648.301822363946,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/293756'}]},
#  {'_id': ObjectId('6757a64a081b88675f2b84a1'),
#   'FHRSID': 878523,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000029844',
#   'BusinessName': 'Brick Lane Brews',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Air side London City Airport',
#   'AddressLine2': 'London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E16 2PX',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-01-18T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.048006'),
#    'latitude': Decimal128('51.503733')},
#   'RightToReply': '',
#   'Distance': 4649.1734848484375,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/878523'}]},
#  {'_id': ObjectId('6757a64a081b88675f2b84a3'),
#   'FHRSID': 902473,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000029852',
#   'BusinessName': 'Pret A Manger',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Retail Unit 2 Gate 3',
#   'AddressLine2': 'West Pier London City Airport',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E16 2PX',
#   'Phone': '',
#   'RatingValue': '2',
#   'RatingKey': 'fhrs_2_en-gb',
#   'RatingDate': '2021-12-06T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 15, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.048006'),
#    'latitude': Decimal128('51.503733')},
#   'RightToReply': '',
#   'Distance': 4649.1734848484375,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/902473'}]},
#  {'_id': ObjectId('6757a64a081b88675f2b84bb'),
#   'FHRSID': 293772,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000002585',
#   'BusinessName': 'The Nuance Group (UK) Limited',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'Duty Free Shop Passenger Terminal',
#   'AddressLine2': 'London City AirportRoyal DocksLondon',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E16 2PX',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2017-07-17T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.047966'),
#    'latitude': Decimal128('51.504112')},
#   'RightToReply': '',
#   'Distance': 4649.188825980348,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/293772'}]},
#  {'_id': ObjectId('6757a64a081b88675f2b84bc'),
#   'FHRSID': 294606,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000016185',
#   'BusinessName': 'WH Smith',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'London City Airport',
#   'AddressLine2': 'Silvertown London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E16 2PX',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2017-07-17T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.0479655750095844'),
#    'latitude': Decimal128('51.5041122436523')},
#   'RightToReply': '',
#   'Distance': 4649.188850403149,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/294606'}]},
#  {'_id': ObjectId('6757a64a081b88675f2b84bd'),
#   'FHRSID': 295107,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000020749',
#   'BusinessName': 'City Bar & Grill',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'London City Airport (Airside)',
#   'AddressLine2': 'London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E16 2PX',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-12-06T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.0479655750095844'),
#    'latitude': Decimal128('51.5041122436523')},
#   'RightToReply': '',
#   'Distance': 4649.188850403149,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/295107'}]},
#  {'_id': ObjectId('6757a64a081b88675f2b84be'),
#   'FHRSID': 295105,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000020747',
#   'BusinessName': 'Cabin Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'London City Airport',
#   'AddressLine2': 'Airside Outside Ledger Building London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E16 2PX',
#   'Phone': '',
#   'RatingValue': '2',
#   'RatingKey': 'fhrs_2_en-gb',
#   'RatingDate': '2022-06-30T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 15, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.047966'),
#    'latitude': Decimal128('51.504112')},
#   'RightToReply': '',
#   'Distance': 4649.188825980348,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/295105'}]},
#  {'_id': ObjectId('6757a64b081b88675f2b869b'),
#   'FHRSID': 294523,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000015222',
#   'BusinessName': 'Jet Centre',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'London City Airport',
#   'AddressLine2': 'Royal Docks London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E16 2PJ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-11T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.0405181497335434'),
#    'latitude': Decimal128('51.5048065185547')},
#   'RightToReply': '',
#   'Distance': 4649.48586971274,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/294523'}]},
#  {'_id': ObjectId('6757a64b081b88675f2b869c'),
#   'FHRSID': 294616,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000016269',
#   'BusinessName': 'Caffè Nero',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'London City Airport Airside Departure Lounge',
#   'AddressLine2': 'Royal Docks London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E16 2PJ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-11-12T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.040518'),
#    'latitude': Decimal128('51.504808')},
#   'RightToReply': '',
#   'Distance': 4649.485929427517,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/294616'}]},
#  {'_id': ObjectId('6757a64d081b88675f2b893c'),
#   'FHRSID': 1427985,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000037871',
#   'BusinessName': 'Mv Sunborn Yacht Hotel',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'AddressLine1': 'Western Gateway',
#   'AddressLine2': 'Royal Victoria Dock',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E16 1XL',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-11-19T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.027107'),
#    'latitude': Decimal128('51.50817')},
#   'RightToReply': '',
#   'Distance': 4650.0981296859945,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1427985'}]},
#  {'_id': ObjectId('6757a64d081b88675f2b8b47'),
#   'FHRSID': 934211,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000030457',
#   'BusinessName': 'Good Hotel London',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Western Gateway Royal Victoria Dock',
#   'AddressLine2': 'Floating Platform next to Emirates Cable Car',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E16 1FA',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-07-16T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.01792'),
#    'latitude': Decimal128('51.507681')},
#   'RightToReply': '',
#   'Distance': 4650.415301460256,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/934211'}]},
#  {'_id': ObjectId('6757a64d081b88675f2b8b6d'),
#   'FHRSID': 1392440,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000037382',
#   'BusinessName': 'La Nonna lina',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Dock Road',
#   'AddressLine2': 'London',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': '',
#   'PostCode': 'E16 1AG',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-10-01T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.0157549995929003'),
#    'latitude': Decimal128('51.5059814453125')},
#   'RightToReply': '',
#   'Distance': 4650.4320658321685,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1392440'}]},
#  {'_id': ObjectId('6757a64d081b88675f2b8b71'),
#   'FHRSID': 558640,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000024155',
#   'BusinessName': 'Wake Up Docklands Limited',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Western Beach Royal Victoria Docks',
#   'AddressLine2': 'London',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': '',
#   'PostCode': 'E16 1AG',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-11-05T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.015742'),
#    'latitude': Decimal128('51.505992')},
#   'RightToReply': '',
#   'Distance': 4650.432926312135,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/558640'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d35'),
#   'FHRSID': 1498024,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000038347',
#   'BusinessName': 'MV Venus Clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Trinity Buoy Wharf',
#   'AddressLine2': 'Orchard Place',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-25T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.00890800673629534'),
#    'latitude': Decimal128('51.507771887145')},
#   'RightToReply': '',
#   'Distance': 4650.747348950763,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1498024'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d80'),
#   'FHRSID': 1090020,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033476',
#   'BusinessName': 'MV Typhoon clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#   'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-12-14T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007816'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805007769328,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090020'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d81'),
#   'FHRSID': 1090017,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033472',
#   'BusinessName': 'MV Moon clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers 3rd flr Clippers House',
#   'AddressLine2': 'Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-09-25T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.0078159999102354'),
#    'latitude': Decimal128('51.5082588195801')},
#   'RightToReply': '',
#   'Distance': 4650.805001170512,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090017'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d82'),
#   'FHRSID': 1090023,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033479',
#   'BusinessName': 'MV Jupiter clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#   'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-12-14T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007816'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805007769328,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090023'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d83'),
#   'FHRSID': 1090021,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033477',
#   'BusinessName': 'MV Monsoon clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#   'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-12-14T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007816'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805007769328,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090021'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d84'),
#   'FHRSID': 1090022,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033478',
#   'BusinessName': 'MV Meteor clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#   'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-12-14T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007816'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805007769328,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090022'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d85'),
#   'FHRSID': 1090019,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033475',
#   'BusinessName': 'MV Tornado clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#   'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-05-02T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007816'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805007769328,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090019'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d86'),
#   'FHRSID': 1090018,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033473',
#   'BusinessName': 'MV Mercury clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers 3rd flr Clippers House',
#   'AddressLine2': 'Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-12-14T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.0078159999102354'),
#    'latitude': Decimal128('51.5082588195801')},
#   'RightToReply': '',
#   'Distance': 4650.805001170512,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090018'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d87'),
#   'FHRSID': 1090027,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033483',
#   'BusinessName': 'MV Cyclone clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#   'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-12-14T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007816'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805007769328,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090027'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d88'),
#   'FHRSID': 1090025,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033481',
#   'BusinessName': 'MV Hurricane clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#   'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-12-14T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007816'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805007769328,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090025'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d89'),
#   'FHRSID': 1090028,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033484',
#   'BusinessName': 'MV Neptune clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#   'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-05-02T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007816'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805007769328,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090028'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d8a'),
#   'FHRSID': 1090024,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033480',
#   'BusinessName': 'MV Galaxy clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#   'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-05-02T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007816'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805007769328,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090024'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d8b'),
#   'FHRSID': 1090016,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033470',
#   'BusinessName': 'MV Sun clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers 3rd flr Clippers House',
#   'AddressLine2': 'Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-12-14T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.0078159999102354'),
#    'latitude': Decimal128('51.5082588195801')},
#   'RightToReply': '',
#   'Distance': 4650.805001170512,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090016'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d8c'),
#   'FHRSID': 293758,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000002546',
#   'BusinessName': 'Mv Storm Clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#   'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-01-11T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007816'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805007769328,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/293758'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d8d'),
#   'FHRSID': 1090026,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033482',
#   'BusinessName': 'MV Aurora clipper',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#   'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-12-03T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007816'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805007769328,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1090026'}]},
#  {'_id': ObjectId('6757a651081b88675f2b8d8e'),
#   'FHRSID': 1450220,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000038259',
#   'BusinessName': 'Canary Wharf 1V',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Trinity Buoy Wharf',
#   'AddressLine2': '64 Orchard Place',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'E14 0JY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-25T00:00:00',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.007815'),
#    'latitude': Decimal128('51.508259')},
#   'RightToReply': '',
#   'Distance': 4650.805044246847,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'http://api.ratings.food.gov.uk/establishments/1450220'}]}]

# %%
#### NOTE TO GRADER, I accidentally re-ran this cell after updating ratingValue to numeric, so it's showing as if it returned nothing. However, originally this cell returned a value showing that ratingValue was a string
#testing the queries
#RatingValue is stored as a string, will need to update all RatingValue entries to int in order to do comparisons (greater than or eq)
list(establishments.find({'RatingValue': {'$regex': '4'}}))
# Out:
# [{'_id': ObjectId('6757a604081b88675f2b0704'),
#   'FHRSID': 647177,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000041489',
#   'BusinessName': 'Wear Bay Bowls Club',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Wear Bay Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT19 6PY',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2014-03-31T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.196408'),
#    'latitude': Decimal128('51.086058')},
#   'RightToReply': '',
#   'Distance': 4591.821311183521,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]},
#  {'_id': ObjectId('6757a604081b88675f2b070a'),
#   'FHRSID': 987206,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075655',
#   'BusinessName': 'The Ships Galley',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'The Ship',
#   'AddressLine2': '23 The Stade',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 6AB',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-07-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.188537'),
#    'latitude': Decimal128('51.08084')},
#   'RightToReply': '',
#   'Distance': 4591.912144538092,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/987206'}]},
#  {'_id': ObjectId('6757a604081b88675f2b070e'),
#   'FHRSID': 805702,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000073219',
#   'BusinessName': 'Dr Legumes - Harbour Arm',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2018-06-08T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/805702'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0717'),
#   'FHRSID': 1396944,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078122',
#   'BusinessName': "Dino's",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-06-06T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1396944'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0721'),
#   'FHRSID': 1058636,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000076450',
#   'BusinessName': 'Babaji',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-08-13T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1058636'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0723'),
#   'FHRSID': 1138444,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077128',
#   'BusinessName': 'Lucky Radish',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-07-26T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1138444'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0725'),
#   'FHRSID': 865873,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000074303',
#   'BusinessName': 'Sole Kitchen - Harbour Arm',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-10-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/865873'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0753'),
#   'FHRSID': 505847,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000038692',
#   'BusinessName': 'The Guildhall',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': '42 The Bayle',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 1SQ',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-11-14T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.182962'),
#    'latitude': Decimal128('51.079301')},
#   'RightToReply': '',
#   'Distance': 4592.057517684561,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/505847'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0754'),
#   'FHRSID': 1241756,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077659',
#   'BusinessName': 'Tips Wok Box',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '4 Tontine Street',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1JU',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2020-03-12T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.18431901931763'),
#    'latitude': Decimal128('51.0809478759766')},
#   'RightToReply': '',
#   'Distance': 4592.069892717788,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1241756'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0755'),
#   'FHRSID': 703619,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000054068',
#   'BusinessName': 'Jolsons',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': '2-6 Tontine Street',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 1JU',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2014-09-05T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.18429'),
#    'latitude': Decimal128('51.080956')},
#   'RightToReply': '',
#   'Distance': 4592.0712551609,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/703619'}]},
#  {'_id': ObjectId('6757a604081b88675f2b075a'),
#   'FHRSID': 289499,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000031634',
#   'BusinessName': 'Valiant Sailor',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'New Dover Road',
#   'AddressLine2': 'Capel-Le-Ferne',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT18 7JJ',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-07-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.201433'),
#    'latitude': Decimal128('51.097794')},
#   'RightToReply': '',
#   'Distance': 4592.079084490149,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289499'}]},
#  {'_id': ObjectId('6757a604081b88675f2b075c'),
#   'FHRSID': 1241750,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077649',
#   'BusinessName': 'The Nook',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '43 Tontine Street',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1JT',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-09-30T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.183894'),
#    'latitude': Decimal128('51.080805')},
#   'RightToReply': '',
#   'Distance': 4592.080016459564,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1241750'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0767'),
#   'FHRSID': 376004,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000029646',
#   'BusinessName': 'Hillside Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '3 George Lane',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1RH',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2020-03-12T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.181832'),
#    'latitude': Decimal128('51.079889')},
#   'RightToReply': '',
#   'Distance': 4592.12077000758,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/376004'}]},
#  {'_id': ObjectId('6757a604081b88675f2b076c'),
#   'FHRSID': 990687,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075113',
#   'BusinessName': 'The Folkestone Wine Company',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '5 Church Street',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1SE',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-10-31T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.181365'),
#    'latitude': Decimal128('51.079542')},
#   'RightToReply': '',
#   'Distance': 4592.12476224034,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/990687'}]},
#  {'_id': ObjectId('6757a604081b88675f2b077d'),
#   'FHRSID': 1466484,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078149',
#   'BusinessName': 'The Beer Shop Folkestone',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': '32 Rendezvous Street',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 1EZ',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-10-23T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')},
#   'RightToReply': '',
#   'Distance': 4592.154065888343,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1466484'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0787'),
#   'FHRSID': 840132,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000073194',
#   'BusinessName': 'Mr Baguette',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '7 Sandgate Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1SB',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-09-30T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.180437'),
#    'latitude': Decimal128('51.07954')},
#   'RightToReply': '',
#   'Distance': 4592.1585054882735,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/840132'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0789'),
#   'FHRSID': 1159680,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077106',
#   'BusinessName': 'Home',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': '61 Tontine Street',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 1JR',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-07-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.1826116'),
#    'latitude': Decimal128('51.0816612')},
#   'RightToReply': '',
#   'Distance': 4592.1588894563265,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1159680'}]},
#  {'_id': ObjectId('6757a604081b88675f2b078a'),
#   'FHRSID': 734835,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000072474',
#   'BusinessName': 'Delish Chicken',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '107 Dover Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1NL',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-03-05T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.185748'),
#    'latitude': Decimal128('51.08472')},
#   'RightToReply': '',
#   'Distance': 4592.159442759842,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/734835'}]},
#  {'_id': ObjectId('6757a604081b88675f2b078c'),
#   'FHRSID': 289512,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000034919',
#   'BusinessName': 'Curry Garden',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '54 Tontine Street',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1JP',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-01-19T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.18279695510864'),
#    'latitude': Decimal128('51.0818634033203')},
#   'RightToReply': '',
#   'Distance': 4592.159726115994,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289512'}]},
#  {'_id': ObjectId('6757a604081b88675f2b078e'),
#   'FHRSID': 534010,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000029249',
#   'BusinessName': 'Wetherspoons',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'The Samuel Peto',
#   'AddressLine2': '23 Rendezvous Street',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1EY',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-06-30T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 10, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.181282'),
#    'latitude': Decimal128('51.080417')},
#   'RightToReply': '',
#   'Distance': 4592.1606334331955,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/534010'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0792'),
#   'FHRSID': 1015765,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075903',
#   'BusinessName': 'Nine Dragons',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '66 Tontine Street',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1JP',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-02-14T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.182753'),
#    'latitude': Decimal128('51.08187')},
#   'RightToReply': '',
#   'Distance': 4592.161575453495,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1015765'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0798'),
#   'FHRSID': 738472,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000072576',
#   'BusinessName': 'Kathmandu House Grilled Tandoori',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '13-15 West Terrace',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 1RR',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-07-28T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 10, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.178909'),
#    'latitude': Decimal128('51.078296')},
#   'RightToReply': '',
#   'Distance': 4592.167494736302,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/738472'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07aa'),
#   'FHRSID': 1210205,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077248',
#   'BusinessName': 'Lilys American Diner',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '71 Sandgate Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 2AF',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-12-18T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.178027'),
#    'latitude': Decimal128('51.078131')},
#   'RightToReply': '',
#   'Distance': 4592.193445269271,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1210205'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07b8'),
#   'FHRSID': 683923,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000071808',
#   'BusinessName': 'The Harp Restrung',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Ground Floor Businees Premises',
#   'AddressLine2': '11 Grace Hill',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1HA',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-02-22T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.180846'),
#    'latitude': Decimal128('51.081337')},
#   'RightToReply': '',
#   'Distance': 4592.211057514895,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/683923'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07c0'),
#   'FHRSID': 444374,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000036997',
#   'BusinessName': 'Holland & Barrett Ltd',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': '80 Sandgate Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2AA',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2012-08-16T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.177468'),
#    'latitude': Decimal128('51.078317')},
#   'RightToReply': '',
#   'Distance': 4592.220799291103,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/444374'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07d5'),
#   'FHRSID': 565884,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000070802',
#   'BusinessName': 'Cafe Tulip',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '3 Shellons Street',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1BW',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-09-17T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.178969'),
#    'latitude': Decimal128('51.080624')},
#   'RightToReply': '',
#   'Distance': 4592.252693070195,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/565884'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07da'),
#   'FHRSID': 289509,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000033273',
#   'BusinessName': 'Southcliff Hotel',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'AddressLine1': 'The Southcliffe Hotel',
#   'AddressLine2': '22-26 The Leas',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 2DY',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-09-10T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.174813'),
#    'latitude': Decimal128('51.076653')},
#   'RightToReply': '',
#   'Distance': 4592.255108060054,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289509'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07dd'),
#   'FHRSID': 987214,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075687',
#   'BusinessName': 'Papa Johns Pizza',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '115 Sandgate Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 2BL',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-09-19T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')},
#   'RightToReply': '',
#   'Distance': 4592.257476451697,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/987214'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07df'),
#   'FHRSID': 465784,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000064902',
#   'BusinessName': 'S & K Folkestone / Premier',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': '137-139 Sandgate Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2BL',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-11-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')},
#   'RightToReply': '',
#   'Distance': 4592.257476451697,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/465784'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07eb'),
#   'FHRSID': 577171,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000030039',
#   'BusinessName': 'Bella Pizza & Pasta',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '124 Sandgate Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2BW',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2018-11-26T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')},
#   'RightToReply': '',
#   'Distance': 4592.287330579803,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/577171'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07ec'),
#   'FHRSID': 1241753,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077653',
#   'BusinessName': 'Browns Coffee House',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '114 Sandgate Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2BW',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-04-21T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')},
#   'RightToReply': '',
#   'Distance': 4592.287330579803,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1241753'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07ef'),
#   'FHRSID': 480354,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000037003',
#   'BusinessName': 'Pizza Hut',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': '128 Sandgate Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2BW',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-12-19T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')},
#   'RightToReply': '',
#   'Distance': 4592.287330579803,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/480354'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07f3'),
#   'FHRSID': 751315,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000041442',
#   'BusinessName': 'Folkestone Baptist Church',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Hill Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT19 6LY',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-10-24T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.189833'),
#    'latitude': Decimal128('51.09221')},
#   'RightToReply': '',
#   'Distance': 4592.291856835031,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/751315'}]},
#  {'_id': ObjectId('6757a604081b88675f2b07fd'),
#   'FHRSID': 289536,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000037364',
#   'BusinessName': 'Windsor Hotel',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'AddressLine1': '5-6 Langhorne Gardens',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2EA',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2015-09-23T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.172728'),
#    'latitude': Decimal128('51.076647')},
#   'RightToReply': '',
#   'Distance': 4592.330876105803,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289536'}]},
#  {'_id': ObjectId('6757a604081b88675f2b0800'),
#   'FHRSID': 289516,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000035257',
#   'BusinessName': 'The Little Fish & Chip Shop',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': '62 Canterbury Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT19 5NL',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2016-10-31T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')},
#   'RightToReply': '',
#   'Distance': 4592.339299517761,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289516'}]},
#  {'_id': ObjectId('6757a606081b88675f2b0808'),
#   'FHRSID': 1204285,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000076800',
#   'BusinessName': 'Sotirios Bar & Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '2A Bouverie Road West',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2RX',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-10-16T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.174748'),
#    'latitude': Decimal128('51.079039')},
#   'RightToReply': '',
#   'Distance': 4592.347028349303,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1204285'}]},
#  {'_id': ObjectId('6757a606081b88675f2b0811'),
#   'FHRSID': 1415743,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000064741',
#   'BusinessName': 'Sidney Street Best One',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '113 Sidney Street',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 6HQ',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-07-04T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.185859'),
#    'latitude': Decimal128('51.090286')},
#   'RightToReply': '',
#   'Distance': 4592.364379152906,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1415743'}]},
#  {'_id': ObjectId('6757a606081b88675f2b0816'),
#   'FHRSID': 376006,
#   'ChangesByServerID': 0,
# ...
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-04-28T00:00:00',
#   'LocalAuthorityCode': '185',
#   'LocalAuthorityName': 'Maidstone',
#   'LocalAuthorityWebSite': 'http://www.maidstone.gov.uk/',
#   'LocalAuthorityEmailAddress': 'EHAdmin@midkent.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.4802277'),
#    'latitude': Decimal128('51.1527919')},
#   'RightToReply': '',
#   'Distance': 4620.471106723243,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1290092'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2ae2'),
#   'FHRSID': 1471045,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000068052',
#   'BusinessName': "Lin's Sushi",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '42 Broad Street',
#   'AddressLine2': 'Seaford',
#   'AddressLine3': 'East Sussex',
#   'AddressLine4': '',
#   'PostCode': 'BN25 1NF',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-07-22T00:00:00',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.102476'),
#    'latitude': Decimal128('50.772819')},
#   'RightToReply': '',
#   'Distance': 4620.475210165006,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1471045'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2aea'),
#   'FHRSID': 1289790,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000173116',
#   'BusinessName': 'Simply Veg',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'Unit 4',
#   'AddressLine2': 'Wallcrouch Business Centre',
#   'AddressLine3': 'High Street',
#   'AddressLine4': 'Wallcrouch',
#   'PostCode': 'TN5 7JR',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-06-10T00:00:00',
#   'LocalAuthorityCode': '106',
#   'LocalAuthorityName': 'Rother',
#   'LocalAuthorityWebSite': 'http://www.rother.gov.uk',
#   'LocalAuthorityEmailAddress': 'envhealth@rother.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.3751953'),
#    'latitude': Decimal128('51.0485675')},
#   'RightToReply': '',
#   'Distance': 4620.486918005373,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1289790'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2aed'),
#   'FHRSID': 1009558,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '17/500585/FOOD',
#   'BusinessName': 'Castle Connections Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Queenborough Library',
#   'AddressLine2': 'Railway Terrace',
#   'AddressLine3': 'Queenborough',
#   'AddressLine4': 'Kent',
#   'PostCode': 'ME11 5AY',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-11-25T00:00:00',
#   'LocalAuthorityCode': '189',
#   'LocalAuthorityName': 'Swale',
#   'LocalAuthorityWebSite': 'http://www.swale.gov.uk',
#   'LocalAuthorityEmailAddress': 'EHAdmin@MidKent.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.747493982315063'),
#    'latitude': Decimal128('51.4160842895508')},
#   'RightToReply': '',
#   'Distance': 4620.488783732212,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1009558'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2aee'),
#   'FHRSID': 1389228,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000067782',
#   'BusinessName': 'The Lanes',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '6 Place Lane',
#   'AddressLine2': 'Seaford',
#   'AddressLine3': 'East Sussex',
#   'AddressLine4': '',
#   'PostCode': 'BN25 1LA',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-06-22T00:00:00',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.1016144'),
#    'latitude': Decimal128('50.7723429')},
#   'RightToReply': '',
#   'Distance': 4620.489870221958,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1389228'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2af3'),
#   'FHRSID': 611867,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '13/00058/FOOD',
#   'BusinessName': 'The Chippy',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': '67 Coppins Road',
#   'AddressLine2': 'Clacton On Sea',
#   'AddressLine3': 'Essex',
#   'AddressLine4': '',
#   'PostCode': 'CO15 3HT',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-08-16T00:00:00',
#   'LocalAuthorityCode': '120',
#   'LocalAuthorityName': 'Tendring',
#   'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#   'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.1441'),
#    'latitude': Decimal128('51.797346')},
#   'RightToReply': '',
#   'Distance': 4620.498015058054,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/611867'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2af6'),
#   'FHRSID': 172201,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000022500',
#   'BusinessName': 'The Kings Head',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Pelham Road',
#   'AddressLine2': 'Seaford',
#   'AddressLine3': 'East Sussex',
#   'AddressLine4': '',
#   'PostCode': 'BN25 1EP',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-03-09T00:00:00',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.100032'),
#    'latitude': Decimal128('50.771136')},
#   'RightToReply': '',
#   'Distance': 4620.504691501915,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/172201'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2afd'),
#   'FHRSID': 172134,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000022330',
#   'BusinessName': 'Seaford Health Store',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': '26 Church Street',
#   'AddressLine2': 'Seaford',
#   'AddressLine3': 'East Sussex',
#   'AddressLine4': '',
#   'PostCode': 'BN25 1LD',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-12-30T00:00:00',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.101067'),
#    'latitude': Decimal128('50.772404')},
#   'RightToReply': '',
#   'Distance': 4620.512422832481,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/172134'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2b00'),
#   'FHRSID': 172229,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000022593',
#   'BusinessName': 'Delicious Doner',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': '12 Clinton Place',
#   'AddressLine2': 'Seaford',
#   'AddressLine3': 'East Sussex',
#   'AddressLine4': '',
#   'PostCode': 'BN25 1NL',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-10-05T00:00:00',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.101369'),
#    'latitude': Decimal128('50.772803')},
#   'RightToReply': '',
#   'Distance': 4620.515735793839,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/172229'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2b01'),
#   'FHRSID': 172240,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000022618',
#   'BusinessName': 'Cafe Seven',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '7 Clinton Place',
#   'AddressLine2': 'Seaford',
#   'AddressLine3': 'East Sussex',
#   'AddressLine4': '',
#   'PostCode': 'BN25 1NL',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-11-09T00:00:00',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.101369'),
#    'latitude': Decimal128('50.772803')},
#   'RightToReply': '',
#   'Distance': 4620.515735793839,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/172240'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2b06'),
#   'FHRSID': 612026,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '1938/FOOD',
#   'BusinessName': 'Sun Yau',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': '18 Broadway',
#   'AddressLine2': 'Jaywick',
#   'AddressLine3': 'Essex',
#   'AddressLine4': '',
#   'PostCode': 'CO15 2EH',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-08-25T00:00:00',
#   'LocalAuthorityCode': '120',
#   'LocalAuthorityName': 'Tendring',
#   'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#   'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('1.119982'),
#    'latitude': Decimal128('51.775153')},
#   'RightToReply': '',
#   'Distance': 4620.523567415892,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/612026'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2b13'),
#   'FHRSID': 717285,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000088576',
#   'BusinessName': 'Redlands Farm Shop',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'Vines Cross Road',
#   'AddressLine2': 'Horam',
#   'AddressLine3': 'East Sussex',
#   'AddressLine4': '',
#   'PostCode': 'TN21 9EE',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-10-15T00:00:00',
#   'LocalAuthorityCode': '107',
#   'LocalAuthorityName': 'Wealden',
#   'LocalAuthorityWebSite': 'http://www.wealden.gov.uk',
#   'LocalAuthorityEmailAddress': 'envhealth@rother.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.259797'),
#    'latitude': Decimal128('50.934392')},
#   'RightToReply': '',
#   'Distance': 4620.549630032383,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/717285'}]},
#  {'_id': ObjectId('6757a614081b88675f2b2b14'),
#   'FHRSID': 172705,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000023807',
#   'BusinessName': 'Brians Newsagents',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'Seaford Railway Station',
#   'AddressLine2': 'Station Approach',
#   'AddressLine3': 'Seaford',
#   'AddressLine4': '',
#   'PostCode': 'BN25 2AR',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-12-02T00:00:00',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.100346'),
#    'latitude': Decimal128('50.772758')},
#   'RightToReply': '',
#   'Distance': 4620.55208664991,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/172705'}]},
#  ...]

# %%
#the next several cells are data cleanup, turning all non-numeric strings in RatingValue to '0'
#this output verifies that all RatingValues are now numeric (note that the next several cells were needed in order to convert all string entries to numbers)
list(establishments.aggregate([{
    
    '$project': 
        {

                'RatingValue': {'$isNumber': '$RatingValue'}
                 
        }
     
}]))
# Out:
# [{'_id': ObjectId('6757a604081b88675f2b0703'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0704'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0705'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0708'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0709'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b070a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b070b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b070c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b070d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b070e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b070f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0710'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0711'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0712'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0713'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0714'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0715'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0716'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0717'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0718'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0719'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b071a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b071b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b071c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b071d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b071e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b071f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0720'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0721'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0722'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0723'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0724'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0725'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0726'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0727'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0728'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0729'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b072a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b072b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b072c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b072d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b072e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b072f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0730'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0732'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0733'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0734'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0735'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0736'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0737'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0738'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b073b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b073c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b073d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b073e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b073f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0740'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0742'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0743'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0744'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0745'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0746'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0748'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0749'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b074c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b074d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b074f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0750'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0751'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0752'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0753'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0754'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0755'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0756'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0757'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0758'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0759'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b075a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b075b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b075c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b075d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b075e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b075f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0760'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0761'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0762'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0763'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0764'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0766'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0767'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0768'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0769'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b076a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b076b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b076c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b076d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b076e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b076f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0770'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0771'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0772'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0773'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0774'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0775'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0776'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0777'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0778'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0779'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b077a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b077b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b077c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b077d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b077e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b077f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0780'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0781'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0782'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0783'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0784'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0785'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0786'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0787'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0788'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0789'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b078a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b078b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b078c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b078d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b078e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b078f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0790'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0791'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0792'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0793'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0794'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0795'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0796'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0797'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0798'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0799'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b079a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b079b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b079c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b079d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b079e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b079f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07a0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07a1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07a2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07a3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07a4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07a5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07a6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07a7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07a8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07a9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07aa'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07ab'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07ac'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07af'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07b0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07b1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07b2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07b3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07b4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07b5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07b6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07b7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07b8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07b9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07ba'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07bc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07bd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07be'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07bf'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07c0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07c1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07c2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07c3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07c4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07c5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07c7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07c8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07c9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07ca'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07cb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07cc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07cd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07ce'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07cf'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07d0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07d1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07d2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07d3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07d4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07d5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07d6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07d7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07d8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07d9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07da'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07db'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07dc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07dd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07de'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07df'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07e0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07e1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07e2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07e3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07e4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07e5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07e6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07e7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07e8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07e9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07ea'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07eb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07ec'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07ed'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07ee'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07ef'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07f0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07f1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07f2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07f3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07f4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07f5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07f6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07f7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07f8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07f9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07fa'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07fb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07fc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07fd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07fe'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b07ff'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0800'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0801'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0802'), 'RatingValue': False},
#  {'_id': ObjectId('6757a604081b88675f2b0803'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0804'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0805'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0806'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0807'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0808'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0809'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b080a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b080b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b080c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b080d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b080e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b080f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0810'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0811'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0812'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0813'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0814'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0815'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0816'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0818'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0819'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b081a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b081b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b081c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b081d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b081e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b081f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0820'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0821'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0822'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0823'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0824'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0825'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0826'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0827'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0828'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0829'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b082a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b082b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b082c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b082d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b082e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b082f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0830'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0831'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0832'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0833'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0834'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0835'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0836'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0837'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0838'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0839'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b083a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b083b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b083d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b083e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0840'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0841'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0842'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0843'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0844'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0845'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0846'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0847'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0848'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0849'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b084a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b084b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b084c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b084d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b084e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b084f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0850'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0851'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0852'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0855'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0856'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0857'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0858'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0859'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b085a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b085b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b085c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b085d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b085e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b085f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0860'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0862'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0868'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0869'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b086a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b086b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b086e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b086f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0873'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0874'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0875'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0877'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0878'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0879'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b087a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b087b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b087c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b087d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b087e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b087f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0880'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0881'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0882'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0884'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0885'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0886'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0887'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0888'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0889'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b088a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b088b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b088c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b088d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b088e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b088f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0890'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0891'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0892'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0893'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0894'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0895'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0896'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0898'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0899'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b089a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b089b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b089d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b089e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b089f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08a0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08a1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08a2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08a3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08a4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08a5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08a6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08a7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08a8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08a9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08aa'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ab'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ac'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ad'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ae'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08b2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08b3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08b5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08b6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08b7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08b8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ba'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08bb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08bc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08bd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08be'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08bf'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08c0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08c1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08c2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08c3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08c4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08c5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08c6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08c7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08c8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08c9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ca'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08cb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08cc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08cd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ce'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08cf'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08d0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08d1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08d2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08d3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08d4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08d5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08d6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08d7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08d8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08d9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08da'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08db'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08dc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08dd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08de'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08df'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08e0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08e1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08e2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08e3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08e4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08e6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08e7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08e8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08e9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ea'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08eb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ec'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ed'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ee'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ef'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08f0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08f1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08f2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08f3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08f4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08f5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08f6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08f7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08f8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08f9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08fa'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08fb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08fc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08fd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08fe'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b08ff'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0900'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0901'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0902'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0903'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0904'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0905'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0906'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0907'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0909'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b090a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b090b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b090c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b090d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b090e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b090f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0910'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0911'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0912'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0913'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0914'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0915'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0916'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0917'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0918'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0919'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b091a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b091b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b091c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b091d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b091e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b091f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0920'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0921'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0922'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0923'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0924'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0925'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0926'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0927'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0928'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0929'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b092a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b092b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b092c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b092d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b092e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b092f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0930'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0931'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0932'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0933'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0934'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0935'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0936'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0937'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0938'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0939'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b093a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b093b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b093c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b093d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b093e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b093f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0940'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0941'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0942'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0943'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0944'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0946'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0947'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0948'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0949'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b094a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b094b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b094c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b094d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b094e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b094f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0950'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0951'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0952'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0953'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0954'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0955'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0956'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0957'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0958'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0959'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b095a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b095b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b095c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b095d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b095e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b095f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0960'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0961'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0962'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0963'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0964'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0965'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0966'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0967'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0968'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0969'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b096a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b096b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b096c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b096d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b096e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b096f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0970'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0971'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0972'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0973'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0974'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0975'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0976'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0977'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0978'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0979'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b097a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b097b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b097c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b097d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b097e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b097f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0980'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0981'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0982'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0983'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0984'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0985'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0986'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0987'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0988'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0989'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b098a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b098b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b098c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b098d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b098e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b098f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0990'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0991'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0992'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0993'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0994'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0995'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0996'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0997'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0998'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0999'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b099a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b099b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b099c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b099d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b099e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b099f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09a0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09a1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09a2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09a3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09a4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09a5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09a6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09a7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09a8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09a9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09aa'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09ab'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09ac'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09ad'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09ae'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09af'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09b0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09b1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09b2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09b3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09b4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09b5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09b6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09b7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09b8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09b9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09ba'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09bb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09bc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09bd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09be'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09bf'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09c0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09c1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09c2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09c3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09c4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09c5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09c6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09c7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09c8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09c9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09ca'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09cb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09cc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09cd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09ce'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09cf'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09d1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09d2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09d3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09d4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09d5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09d6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09d7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09d8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09d9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09da'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b09db'), 'RatingValue': False},
# ...
#  {'_id': ObjectId('6757a606081b88675f2b0a3b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a3c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a3d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a3e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a41'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a43'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a44'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a45'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a46'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a47'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a48'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a49'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a4b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a4c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a4d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a4e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a4f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a50'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a53'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a54'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a55'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a56'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a58'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a59'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a5a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a5e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a60'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a61'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a62'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a63'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a64'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a65'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a66'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a6a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a6c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a6e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a6f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a70'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a73'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a74'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a75'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a77'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a79'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a7a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a7b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a7c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a7d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a7e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a7f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a80'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a81'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a82'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a83'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a86'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a8c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a8d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a93'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a94'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a97'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a98'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a99'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a9b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a9d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a9e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0a9f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aa0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aa1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aa8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aa9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aad'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aae'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ab0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ab1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ab2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ab3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ab9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aba'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0abb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0abc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0abd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ac5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ac7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0acb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0acc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0acd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ace'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0acf'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ad0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ad5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0adc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0add'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ade'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0adf'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ae0'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ae1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ae2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ae3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ae4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ae6'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ae7'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ae8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0ae9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aea'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aeb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aec'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aed'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aee'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0af1'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0af2'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0af3'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0af4'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0af5'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0af8'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0af9'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0afa'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0afb'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0afc'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0afd'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0afe'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0aff'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b00'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b01'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b02'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b03'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b04'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b05'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b06'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b07'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b08'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b09'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b0b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b0d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b0e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b0f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b10'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b11'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b12'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b13'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b14'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b16'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b18'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b19'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b1a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b1b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b1c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b1d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b1e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b1f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b20'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b22'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b23'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b24'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b25'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b26'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b27'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b28'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b29'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b2a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b2b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b2d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b2e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b2f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b30'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b31'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b32'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b33'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b34'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b38'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b39'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b3a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b3b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b3c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b3d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b3e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b3f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b40'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b41'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b42'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b43'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b44'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b45'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b46'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b47'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b48'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b4a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b4b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b4c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b4d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b4e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b4f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b50'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b51'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b52'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b53'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b54'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b55'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b56'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b57'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b58'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b5a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b5b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b5c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b5d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b60'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b61'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b62'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b63'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b64'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b65'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b66'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b67'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b68'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b69'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b6a'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b6b'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b6c'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b6d'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b6e'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b6f'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b70'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b71'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b72'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b73'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b75'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b76'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b77'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b78'), 'RatingValue': False},
#  {'_id': ObjectId('6757a606081b88675f2b0b79'), 'RatingValue': False},
#  ...]

# %%
#set all RatingValues to decimal
establishments.update_many({}, [ {'$set':{'RatingValue': {'$toDecimal': '$RatingValue'} }}])
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
#set all empty RatingValues to 0
establishments.update_many({'RatingValue':''}, [ {'$set':{'RatingValue': 0 }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#set all 'AwaitingInspection' Rating Values to None
establishments.update_many({'RatingValue':'AwaitingInspection'}, [ {'$set':{'RatingValue': None }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#set all 'Awaiting Inspection' Rating Values to None
establishments.update_many({'RatingValue':'Awaiting Inspection'}, [ {'$set':{'RatingValue': None }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#set all 'Exempt' Rating Values to None
establishments.update_many({'RatingValue':'Exempt'}, [ {'$set':{'RatingValue': None }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#set all 'AwaitingPublication' Rating Values to None
establishments.update_many({'RatingValue':'AwaitingPublication'}, [ {'$set':{'RatingValue': None }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#set all 'Pass' Rating Values to None
establishments.update_many({'RatingValue':'Pass'}, [ {'$set':{'RatingValue': None }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#testing that 'RatingValue' can now be compared numerically
len(list(establishments.find({'RatingValue': {'$gte': 4}})))
# Out:
# 31257

# %%
#testing that 'RatingValue' can now be compared numerically
len(list(establishments.find({'RatingValue': {'$gte': 4}})))
# Out:
# 31257

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName' :{'$regex': "London"},
         'RatingValue': {'$gte': 4}
         }
results = list(establishments.find(query))
# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))
# Display the first document in the results using pprint
pprint(results[0])
# Out:
# 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': Decimal128('4'),
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6757a622081b88675f2b3c50'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
london_rating_4_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(f"Number of rows: {len(london_rating_4_df)}")
# Display the first 10 rows of the DataFrame
london_rating_4_df.head(10)
# Out:
# Number of rows: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  6757a622081b88675f2b3c50   621707                  0
# 1  6757a624081b88675f2b3f76  1130836                  0
# 2  6757a62e081b88675f2b4ac3   293783                  0
# 3  6757a633081b88675f2b58c3  1315095                  0
# 4  6757a633081b88675f2b58c4   294474                  0
# 5  6757a636081b88675f2b5fcc   294900                  0
# 6  6757a648081b88675f2b80da   293756                  0
# 7  6757a64a081b88675f2b84a1   878523                  0
# 8  6757a64a081b88675f2b84bb   293772                  0
# 9  6757a64a081b88675f2b84bc   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000002585         The Nuance Group (UK) Limited
# 9             PI/000016185                              WH Smith
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                  Duty Free Shop Passenger Terminal
# 9                                London City Airport
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8  London City AirportRoyal DocksLondon               ...
# 9                     Silvertown London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8     {'longitude': 0.047966, 'latitude': 51.504112}
# 9  {'longitude': 0.0479655750095844, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188826            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
#find penang flavor's lat and lon
list(establishments.find({'BusinessName':'Penang Flavours'}))
# Out:
# [{'_id': ObjectId('6757a846d595cfe94e21ea43'),
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '1',
#   'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'PostCode': 'SE18 7DY',
#   'Phone': '',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': Decimal128('0.08384000'),
#    'latitude': Decimal128('51.49014200')},
#   'RightToReply': '',
#   'Distance': 4623.972328074718,
#   'NewRatingPending': True,
#   'RatingValue': None}]

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000
query = {'RatingValue': {'$eq': 5},
         'geocode.latitude':{'$gte': (latitude - degree_search), '$lte': (latitude + degree_search)},
         'geocode.longitude':{'$gte': (longitude - degree_search), '$lte': (longitude + degree_search)}
         }
sort =  [('scores.Hygiene', 1)] # for sorting, 1 is ascending, -1 is descending
limit = 5
results = list(establishments.find(query).sort(sort).limit(limit))
pprint(results)
# Out:
# [{'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': Decimal128('5'),
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6757a647081b88675f2b7a77'),
#   'geocode': {'latitude': Decimal128('51.4875335693359'),
#               'longitude': Decimal128('0.0925370007753372')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '35 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Atlantic Fish Bar',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.974611855838,
#   'FHRSID': 694478,
#   'LocalAuthorityBusinessID': 'PI/000086506',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PR',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': Decimal128('5'),
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6757a647081b88675f2b7aaf'),
#   'geocode': {'latitude': Decimal128('51.4867296'),
#               'longitude': Decimal128('0.0912164')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694478',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Plumstead Manor Nursery',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.9740101340385,
#   'FHRSID': 695241,
#   'LocalAuthorityBusinessID': 'PI/000179088',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1QG',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': Decimal128('5'),
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6757a647081b88675f2b7aac'),
#   'geocode': {'latitude': Decimal128('51.481517791748'),
#               'longitude': Decimal128('0.0859939977526665')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': Decimal128('5'),
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6757a647081b88675f2b7a67'),
#   'geocode': {'latitude': Decimal128('51.4871482849121'),
#               'longitude': Decimal128('0.0924199968576431')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': Decimal128('5'),
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6757a647081b88675f2b7a94'),
#   'geocode': {'latitude': Decimal128('51.4873437'),
#               'longitude': Decimal128('0.09208')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %%
# Convert result to Pandas DataFrame
near_penang_df = pd.DataFrame(results)
near_penang_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6757a647081b88675f2b7a77  1380578                  0
# 1  6757a647081b88675f2b7aaf   694478                  0
# 2  6757a647081b88675f2b7aac   695241                  0
# 3  6757a647081b88675f2b7a67   695223                  0
# 4  6757a647081b88675f2b7a94   694609                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0                    14425  Howe and Co Fish and Chips - Van 17
# 1             PI/000086506                    Atlantic Fish Bar
# 2             PI/000179088              Plumstead Manor Nursery
# 3             PI/000178842                              Iceland
# 4             PI/000116619                            Volunteer
#
#                             BusinessType  BusinessTypeID  \
# 0                         Mobile caterer            7846
# 1                 Takeaway/sandwich shop            7844
# 2                        Caring Premises               5
# 3  Retailers - supermarkets/hypermarkets            7840
# 4                      Pub/bar/nightclub            7843
#
#                                         AddressLine1 AddressLine2  \
# 0  Restaurant And Premises 107A Plumstead High St...
# 1                                   35 Lakedale Road
# 2               Plumstead Manor School Old Mill Road
# 3                    144 - 146 Plumstead High Street
# 4                    130 - 132 Plumstead High Street
#
#   AddressLine3  ...             LocalAuthorityWebSite  \
# 0    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 1    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 2    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 3    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 4    Plumstead  ...  http://www.royalgreenwich.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0  health@royalgreenwich.gov.uk
# 1  health@royalgreenwich.gov.uk
# 2  health@royalgreenwich.gov.uk
# 3  health@royalgreenwich.gov.uk
# 4  health@royalgreenwich.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.0925370007753372, 'latitude': ...
# 1   {'longitude': 0.0912164, 'latitude': 51.4867296}
# 2  {'longitude': 0.0859939977526665, 'latitude': ...
# 3  {'longitude': 0.0924199968576431, 'latitude': ...
# 4     {'longitude': 0.09208, 'latitude': 51.4873437}
#
#       Distance NewRatingPending  \
# 0  4646.955931            False
# 1  4646.974612            False
# 2  4646.974010            False
# 3  4646.946071            False
# 4  4646.965635            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match_query = {'$match': {'scores.Hygiene': {'$eq': 0}}}
group_query = {'$group': {'_id': {'LocalAuthorityName': '$LocalAuthorityName'},
                          'count':{'$sum':1}
                          }}
sort_values = {'$sort': {'count': -1}}

pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))
results
# Print the number of documents in the result
print(f"Number of documents in result: {establishments.count_documents(query)}")
# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of documents in result: 87
# [{'_id': {'LocalAuthorityName': 'Thanet'}, 'count': 1130},
#  {'_id': {'LocalAuthorityName': 'Greenwich'}, 'count': 882},
#  {'_id': {'LocalAuthorityName': 'Maidstone'}, 'count': 713},
#  {'_id': {'LocalAuthorityName': 'Newham'}, 'count': 711},
#  {'_id': {'LocalAuthorityName': 'Swale'}, 'count': 686},
#  {'_id': {'LocalAuthorityName': 'Chelmsford'}, 'count': 680},
#  {'_id': {'LocalAuthorityName': 'Medway'}, 'count': 672},
#  {'_id': {'LocalAuthorityName': 'Bexley'}, 'count': 607},
#  {'_id': {'LocalAuthorityName': 'Southend-On-Sea'}, 'count': 586},
#  {'_id': {'LocalAuthorityName': 'Tendring'}, 'count': 542}]

# %%
#debug verification
query = {'scores.Hygiene': {'$eq': 0}, 'LocalAuthorityName': {'$regex': "London"}}
len(list(establishments.find(query)))
# Out:
# 28

# %%
# Convert the result to a Pandas DataFrame
hygiene_0_by_authority_df = pd.DataFrame(results)
hygiene_0_by_authority_df
# Display the number of rows in the DataFrame
len(hygiene_0_by_authority_df)
# Display the first 10 rows of the DataFrame
hygiene_0_by_authority_df.head(10)
# Out:
#                                          _id  count
# 0           {'LocalAuthorityName': 'Thanet'}   1130
# 1        {'LocalAuthorityName': 'Greenwich'}    882
# 2        {'LocalAuthorityName': 'Maidstone'}    713
# 3           {'LocalAuthorityName': 'Newham'}    711
# 4            {'LocalAuthorityName': 'Swale'}    686
# 5       {'LocalAuthorityName': 'Chelmsford'}    680
# 6           {'LocalAuthorityName': 'Medway'}    672
# 7           {'LocalAuthorityName': 'Bexley'}    607
# 8  {'LocalAuthorityName': 'Southend-On-Sea'}    586
# 9         {'LocalAuthorityName': 'Tendring'}    542
